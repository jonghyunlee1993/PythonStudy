# %%
from igramscraper.instagram import Instagram

instagram = Instagram()

# authentication supported
instagram.with_credentials('green19880@naver.com', 'tjrnlvh5149')
instagram.login(force=False,two_step_verificator=True)
# Out:
# {'cookie': 'csrftoken=5NfPrc1e7qG7KpcG2OCVhXfmOMoDM9Js; ds_user_id=6673149270; ig_did=C2EDA636-8EFE-4E41-B53D-00C7C49C6EE3; rur=FTW; sessionid=6673149270%3Ayjn7hVO6m8RjGH%3A18; shbid=13474; shbts=1576660460.7158582; mid=Xfnt6wAEAAHEUyBl3z_tfnfdSKf5; ',
#  'referer': 'https://www.instagram.com/',
#  'x-csrftoken': '5NfPrc1e7qG7KpcG2OCVhXfmOMoDM9Js',
#  'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'}

# %%
medias = instagram.get_current_top_medias_by_tag_name('성수')

# %%
print(medias)
# Out:
# [<igramscraper.model.media.Media object at 0x107b78e48>, <igramscraper.model.media.Media object at 0x107b78a20>, <igramscraper.model.media.Media object at 0x10873dfd0>, <igramscraper.model.media.Media object at 0x10873deb8>, <igramscraper.model.media.Media object at 0x10873de10>, <igramscraper.model.media.Media object at 0x10873dda0>, <igramscraper.model.media.Media object at 0x10873de48>, <igramscraper.model.media.Media object at 0x10873def0>, <igramscraper.model.media.Media object at 0x107ced198>]

# %%
media = medias[0]

print(media)
print(media.owner)
# Out:
# Media Info:
# 'Id: 2201366378293180485
# Shortcode: B6M0w7GpzhF
# Created at: 1576643343
# Caption: 🖤
# Number of comments: 0
# Number of likes: 126
# Link: https://www.instagram.com/p/B6M0w7GpzhF
# Hig res image: https://scontent-icn1-1.cdninstagram.com/v/t51.2885-15/e35/p1080x1080/79141955_106093887463863_3536031156277942373_n.jpg?_nc_ht=scontent-icn1-1.cdninstagram.com&_nc_cat=103&oh=0cbaae302948cf2a1023a0290e10da7a&oe=5E96E013
# Media type: image
#
#
# Account info:
# Id: 1421141722
# Username: None
# Full Name: None
# Bio: None
# Profile Pic Url: None
# External url: None
# Number of published posts: -
# Number of followers: 0
# Number of follows: 0
# Is private: False
# Is verified: False

# %%
print(media.created_time)
# Out:
# 1576643343

# %%
medias = instagram.get_medias_by_tag('성수', count=100)

for media in medias:
#     print(media)
#     print('Account info:')
    account = media.owner
#     print('Id', account.identifier)
    print('Time', media.created_time)
    # print('Username', account.username)
    # print('Full Name', account.full_name)
    # print('Profile Pic Url', account.get_profile_picture_url_hd())
    print('--------------------------------------------------')
# Out:
# Time 1576660771
# --------------------------------------------------
# Time 1576660701
# --------------------------------------------------
# Time 1576660649
# --------------------------------------------------
# Time 1576660412
# --------------------------------------------------
# Time 1576660346
# --------------------------------------------------
# Time 1576660323
# --------------------------------------------------
# Time 1576660308
# --------------------------------------------------
# Time 1576660299
# --------------------------------------------------
# Time 1576660283
# --------------------------------------------------
# Time 1576660033
# --------------------------------------------------
# Time 1576659804
# --------------------------------------------------
# Time 1576659725
# --------------------------------------------------
# Time 1576659135
# --------------------------------------------------
# Time 1576659104
# --------------------------------------------------
# ...

# %%
media.created_time
# Out:
# 1576657310

# %%
media.
